# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Declarations
#
# * Fixed point function definition (`fixed_point`)
# * Numeric Backward Euler step (`ux`)

# %%
def fixed_point(x0, fx, eps, max_loop = 100000):
    stop_point_val = float('inf')
    x = x0
    prev_fx = x0
    for i in range(max_loop):
        if stop_point_val < eps: break
        prev_fx = x
        x = fx(x)
        stop_point_val = abs(x - prev_fx)
    return x

# %%
def ux(t_n, u_n1 = 1, h1 = 0.1, err = 1e-6):
    return fixed_point(u_n1, lambda u: u_n1 + h1*(u-t_n)/(u+t_n), err)

# %% [markdown]
# ## Evaluating Differential Equation Numerically

# %%
def evaluate(h1 = 0.1, init = 0, end = 6.5):
    t_n = np.arange(init, end, h1)
    u_n = [1]
    for i in range(1,len(t_n)):
        u_n.append(ux(t_n[i], u_n[i-1]))
    return t_n, u_n

# %% [markdown]
# ## Plotting

# %%
t_n, u_n = evaluate()

fig, ax = plt.subplots()

plt.plot(t_n, u_n, label="u(x)")
ax.set_axisbelow(True)
ax.minorticks_on()
ax.grid(which='major', linestyle='-', linewidth='0.5', color='red')
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title("Numeric solution of Differential Equation")
plt.legend()

ax = plt.gca()

# %% [markdown]
# # Analytic solution by fixed point method to Analytic Solution
#
# * Analytic Solution: $\frac{1}{2}log\left(t^2 + u^2\right) + tan^{-1}\left(\frac{u(t)}{t}\right) = 1.5708$
#
# ## Fixed point approximation:
#
# $\frac{1}{2}log\left(t^2 + u^2\right) + tan^{-1}\left(\frac{u(t)}{t}\right) = 1.5708 \Leftrightarrow
#  log\left(t^2 + u^2\right) + 2 \cdot tan^{-1}\left(\frac{u(t)}{t}\right) = 3.1416 \Leftrightarrow
# $
#
# ... To continue tomorrow
